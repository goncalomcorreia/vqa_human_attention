# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
# %matplotlib inline


def running_mean(l, N):
    sum = 0
    result = list( 0 for x in l)
    for i in range( 0, N ):
        sum = sum + l[i]
        result[i] = sum / (i+1)
    for i in range( N, len(l) ):
        sum = sum - l[i-N] + l[i]
        result[i] = sum / N
    return result

# %% [markdown]
# # First vs. Second Attention Layer,  Joint Cost

# %%
acc_valid = []
err_valid = []
err_map_valid = []
x_axis_valid = []
x_axis_main_train = []
x_axis_sub_train = []
acc_train = []
err_train = []
err_map_train = []
labels = ['second_att', 'first_att', 'baseline']  

plot = 'joint_cost_second_att_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

plot = 'joint_cost_first_att_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

plot = 'baseline_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], err_map_valid[i], label='Val '+labels[i])
    #ax1.plot(x_axis_sub_train[i], err_map_train[i], label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':6})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Human Att Map Error')
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], acc_valid[i], label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], acc_train[i], label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Accuracy')
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], err_valid[i], label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], err_train[i], label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Answer Error')
#ax1.set_yscale('log')
ax1.set_ylim(1.8,2.5)
ax1.grid()
fig.show()

# %% [markdown]
# # Probability Alternative Tasks

# %%
acc_valid = []
err_valid = []
err_map_valid = []
x_axis_valid = []
x_axis_main_train = []
x_axis_sub_train = []
acc_train = []
err_train = []
err_map_train = []
labels = ['0.25', '0.5', '0.75', 'baseline']  

plot = 'alt_ce_0.25_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

plot = 'alt_ce_0.5_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])
    
plot = 'alt_ce_0.75_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

plot = 'baseline_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], err_map_valid[i], label='Val '+labels[i])
    #ax1.plot(x_axis_sub_train[i], err_map_train[i], label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':6})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Human Att Map Error')
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], acc_valid[i], label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], acc_train[i], label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Accuracy')
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], err_valid[i], label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], err_train[i], label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Answer Error')
#ax1.set_yscale('log')
ax1.set_ylim(1.8,3.)
ax1.grid()
fig.show()

# %% [markdown]
# # Baseline vs. KL, p=0.8, specialized

# %%
acc_valid = []
err_valid = []
err_map_valid = []
x_axis_valid = []
x_axis_main_train = []
x_axis_sub_train = []
acc_train = []
err_train = []
err_map_train = []
labels = ['baseline', 'Alt']  

plot_dir = '/afs/inf.ed.ac.uk/user/s16/s1670404/vqa_human_attention/expt/baseline/'
plot = 'baseline_plot_details.npz'

with np.load(plot_dir+plot) as data:
    half = data['valid_error'].shape[0]/2
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    #err_map_valid.append(data['valid_error_map'])
    #err_map_train.append(data['train_error_map'])
    #x_axis_sub_train.append(data['sub_x_axis'])
    #x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

plot_dir = '/afs/inf.ed.ac.uk/user/s16/s1670404/vqa_human_attention/expt/tuning/'
plot = 'alt_kl_0.8_spec_plot_details.npz'

with np.load(plot_dir+plot) as data:
    print data.keys()
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])
# Out:
# ['main_x_axis', 'train_accuracy', 'train_error', 'valid_error', 'sub_x_axis', 'x_axis_epochs', 'valid_error_map', 'valid_accuracy', 'train_error_map']

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
ax1.plot(x_axis_valid[-1], running_mean(err_map_valid[-1],5), label='Val '+labels[-1])
ax1.plot(x_axis_sub_train[-1], running_mean(err_map_train[-1],5), label='Train '+labels[-1])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Human Att Map Error')
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
ax1.plot(x_axis_valid[0], running_mean(acc_valid[0],3), label='Val '+labels[0])
#ax1.plot(x_axis_valid[0], acc_train[0], label='Train '+labels[0])
ax1.plot(x_axis_valid[1], running_mean(acc_valid[1],3), label='Val '+labels[1])
#ax1.plot(x_axis_main_train[0], acc_train[1], label='Train '+labels[1])
ax1.set_ylim(0.45,0.55)
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Accuracy')
ax1.yaxis.set_ticks(np.arange(0.45,0.55,0.005))
ax1.grid(True)
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], running_mean(err_valid[i], 5), label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], err_train[i], label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Answer Error')
#ax1.set_yscale('log')
ax1.set_ylim(1.6,2.)
ax1.grid()
fig.show()

# %% [markdown]
# # Attention Maps

# %%
acc_valid = []
err_valid = []
err_map_valid = []
x_axis_valid = []
x_axis_main_train = []
x_axis_sub_train = []
acc_train = []
err_train = []
err_map_train = []
labels = ['sgd 1e-4','2 conv', 'inception']  

plot_dir = '/Users/goncalocorreia/vqa_human_attention/expt/tuning/'

plot = 'sgd_1e-4_kl_plot_details.npz'

with np.load(plot_dir+plot) as data:
    #err_valid.append(data['valid_error'])
    #acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    #x_axis_sub_train.append(data['sub_x_axis'])
    #x_axis_main_train.append(data['main_x_axis'])
    #err_train.append(data['train_error'])
    #acc_train.append(data['train_accuracy'])
    
plot = 'maps_inception_plot_details.npz'

with np.load(plot_dir+plot) as data:
    #err_valid.append(data['valid_error'])
    #acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    #x_axis_sub_train.append(data['sub_x_axis'])
    #x_axis_main_train.append(data['main_x_axis'])
    #err_train.append(data['train_error'])
    #acc_train.append(data['train_accuracy'])
    
plot = 'maps_more_inception_5x5_plot_details.npz'

with np.load(plot_dir+plot) as data:
    #err_valid.append(data['valid_error'])
    #acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    #x_axis_sub_train.append(data['sub_x_axis'])
    #x_axis_main_train.append(data['main_x_axis'])
    #err_train.append(data['train_error'])
    #acc_train.append(data['train_accuracy'])

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], err_map_valid[i], label='Val '+labels[i])
    ax1.plot(x_axis_valid[i], running_mean(err_map_train[i],5), label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':10})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Human Att Map Error')
ax1.yaxis.set_ticks(np.arange(0.16,0.28,0.01))
ax1.grid(True)
fig.show()
# Out:
# /Users/goncalocorreia/miniconda2/envs/vqa/lib/python2.7/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# # HSAN Tuning

# %%
acc_valid = []
err_valid = []
err_map_valid = []
x_axis_valid = []
x_axis_main_train = []
x_axis_sub_train = []
acc_train = []
err_train = []
err_map_train = []
labels = ['0.1 with conv','noLB 0.5 no conv', '0.5 fixed']  

plot_dir = '/afs/inf.ed.ac.uk/group/synproc/Goncalo/expt/tuning/'

plot = 'tune_hsan_deepfix_lmda_0.1_noLB_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])
    
plot = 'tune_hsan_deepfix_lmda_0.5_second_noLB_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

plot = 'tune_hsan_deepfix_lmda_0.5_less_fixed_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], running_mean(err_map_valid[i],10), label='Val '+labels[i])
    ax1.plot(x_axis_sub_train[i], running_mean(err_map_train[i],10), label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Human Att Map Error')
#ax1.set_xlim(0.,5.)
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], acc_valid[i], label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], running_mean(acc_train[i],10), label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Accuracy')
#ax1.set_ylim(0.3,0.45)
ax1.grid()
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], running_mean(err_valid[i],5), label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], running_mean(err_train[i],10), label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Answer Error')
#ax1.set_yscale('log')
ax1.set_ylim(1.9,2.4)
#ax1.set_xlim(0,5)
ax1.grid()
fig.show()

# %% [markdown]
# # HSAN

# %%
acc_valid = []
err_valid = []
err_map_valid = []
x_axis_valid = []
x_axis_main_train = []
x_axis_sub_train = []
acc_train = []
err_train = []
err_map_train = []
labels = ['best', 'old', 'new']  

plot_dir = '/afs/inf.ed.ac.uk/group/synproc/Goncalo/expt/tuning/'

plot = 'hsan_inception_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])
    
plot = 'hsan_deepfix_lmda_0.01_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

plot = 'tune_hsan_deepfix_lmda_0.5_first_plot_details.npz'

with np.load(plot_dir+plot) as data:
    err_valid.append(data['valid_error'])
    acc_valid.append(data['valid_accuracy'])
    x_axis_valid.append(data['x_axis_epochs'])
    err_map_valid.append(data['valid_error_map'])
    err_map_train.append(data['train_error_map'])
    x_axis_sub_train.append(data['sub_x_axis'])
    x_axis_main_train.append(data['main_x_axis'])
    err_train.append(data['train_error'])
    acc_train.append(data['train_accuracy'])

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], running_mean(err_map_valid[i],10), label='Val '+labels[i])
    ax1.plot(x_axis_sub_train[i], running_mean(err_map_train[i],10), label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Human Att Map Error')
ax1.set_ylim(0.2,.3)
ax1.set_xlim(0,5)
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], acc_valid[i], label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], running_mean(acc_train[i],10), label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Accuracy')
#ax1.set_ylim(0.3,0.45)
ax1.grid()
fig.show()

# %%
fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)
for i in xrange(len(x_axis_valid)):
    ax1.plot(x_axis_valid[i], running_mean(err_valid[i],5), label='Val '+labels[i])
    #ax1.plot(x_axis_main_train[i], running_mean(err_train[i],10), label='Train '+labels[i])
ax1.legend(loc=0,prop={'size':16})
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Answer Error')
#ax1.set_yscale('log')
ax1.set_ylim(1.6,1.8)
#ax1.set_xlim(0,5)
ax1.grid()
fig.show()
